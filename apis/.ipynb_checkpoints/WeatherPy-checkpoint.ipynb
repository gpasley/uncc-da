# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %%
cities
# Out:
# ['ushuaia',
#  'busselton',
#  'belushya guba',
#  'kapaa',
#  'sorong',
#  'vaini',
#  'eregli',
#  'tasiilaq',
#  'camocim',
#  'balabac',
#  'comodoro rivadavia',
#  'adrar',
#  'daru',
#  'tiksi',
#  'vila velha',
#  'tatawin',
#  'yellowknife',
#  'dunedin',
#  'albany',
#  'bluff',
#  'ribeira grande',
#  'pyapon',
#  'sindor',
#  'rikitea',
#  'nagyigmand',
#  'illoqqortoormiut',
#  'indramayu',
#  'arraial do cabo',
#  'punta arenas',
#  'cape town',
#  'brzeg dolny',
#  'atuona',
#  'dikson',
#  'mataura',
#  'touros',
#  'pochutla',
#  'castro',
#  'ahipara',
#  'seymchan',
#  'hokitika',
#  'jalu',
#  'maningrida',
#  'chernyshevskiy',
#  'russell',
#  'hithadhoo',
#  'yaan',
#  'hofn',
#  'sola',
#  'ryotsu',
#  'taolanaro',
#  'ubatuba',
#  'clyde river',
#  'bardiyah',
#  'vestmannaeyjar',
#  'qaanaaq',
#  'lithgow',
#  'east london',
#  'son la',
#  'kismayo',
#  'hobart',
#  'sawtell',
#  'allonnes',
#  'victoria',
#  'lagoa',
#  'olafsvik',
#  'hilo',
#  'maine-soroa',
#  'podyuga',
#  'puerto ayora',
#  'marawi',
#  'tateyama',
#  'gazojak',
#  'chuy',
#  'port alfred',
#  'mar del plata',
#  'hermanus',
#  'klaksvik',
#  'gizo',
#  'ulladulla',
#  'jamestown',
#  'miles city',
#  'bethel',
#  'amderma',
#  'soufriere',
#  'torbay',
#  'panaba',
#  'oistins',
#  'upernavik',
#  'porangatu',
#  'ballitoville',
#  'rosetta',
#  'tidore',
#  'entre rios',
#  'khatanga',
#  'ikom',
#  'cayenne',
#  'leningradskiy',
#  'provideniya',
#  'barentsburg',
#  'georgetown',
#  'tuktoyaktuk',
#  'dwarka',
#  'ramasukha',
#  'dakar',
#  'oktyabrskiy',
#  'kedrovyy',
#  'karaul',
#  'havelock',
#  'okha',
#  'hamilton',
#  'meulaboh',
#  'montego bay',
#  'cape canaveral',
#  'newport',
#  'chaupimarca',
#  'chachapoyas',
#  'xapuri',
#  'marcona',
#  'wa',
#  'erhlin',
#  'padang',
#  'nadadores',
#  'golfito',
#  'saint-philippe',
#  'bilibino',
#  'aklavik',
#  'piacabucu',
#  'la romana',
#  'aksarka',
#  'bredasdorp',
#  'geraldton',
#  'praia',
#  'butaritari',
#  'temiscaming',
#  'port blair',
#  'cidreira',
#  'tambura',
#  'carutapera',
#  'saldanha',
#  'thompson',
#  'codrington',
#  'saint george',
#  'new norfolk',
#  'tabiauea',
#  'lethem',
#  'pisco',
#  'zaraza',
#  'san patricio',
#  'cherskiy',
#  'namibe',
#  'constitucion',
#  'wum',
#  'avarua',
#  'los llanos de aridane',
#  'coquimbo',
#  'yeppoon',
#  'tautira',
#  'atambua',
#  'carnarvon',
#  'balkhash',
#  'karpogory',
#  'bathsheba',
#  'awjilah',
#  'srednekolymsk',
#  'saleaula',
#  'panguna',
#  'palabuhanratu',
#  'road town',
#  'kaitangata',
#  'bowen',
#  'banjarmasin',
#  'margate',
#  'zyryanka',
#  'haines junction',
#  'cosolapa',
#  'salalah',
#  'caucaia',
#  'airai',
#  'korhogo',
#  'labytnangi',
#  'ecatzingo',
#  'nikolskoye',
#  'labuhan',
#  'fiditi',
#  'zabid',
#  'barrow',
#  'kahului',
#  'port-gentil',
#  'stornoway',
#  'iquique',
#  'bambous virieux',
#  'queanbeyan',
#  'red bluff',
#  'makakilo city',
#  'saskylakh',
#  'sambava',
#  'vagur',
#  'abashiri',
#  'maragogi',
#  'olinda',
#  'aykhal',
#  'kodiak',
#  'la ronge',
#  'vardo',
#  'benemerito de las americas',
#  'san-pedro',
#  'ust-nera',
#  'havre-saint-pierre',
#  'port elizabeth',
#  'ponta do sol',
#  'agadir',
#  'ilulissat',
#  'fort nelson',
#  'egvekinot',
#  'bogande',
#  'yumen',
#  'faya',
#  'florianopolis',
#  'samusu',
#  'chapais',
#  'hasaki',
#  'wyszkow',
#  'arcata',
#  'kaa-khem',
#  'quelimane',
#  'tual',
#  'bengkulu',
#  'inhambane',
#  'longjiang',
#  'nizhneyansk',
#  'darhan',
#  'ostrovnoy',
#  'amarante do maranhao',
#  'hundested',
#  'kiunga',
#  'pitimbu',
#  'kyren',
#  'narsaq',
#  'lebu',
#  'domoni',
#  'urdzhar',
#  'laukaa',
#  'laguna',
#  'iqaluit',
#  'mossendjo',
#  'caborca',
#  'ugoofaaru',
#  'vaitupu',
#  'sataua',
#  'vostok',
#  'pendencias',
#  'kachug',
#  'kontagora',
#  'acapulco',
#  'huilong',
#  'sabang',
#  'katsuura',
#  'sitka',
#  'grand bend',
#  'severo-kurilsk',
#  'salinopolis',
#  'coihaique',
#  'kavieng',
#  'cabrobo',
#  'souillac',
#  'mys shmidta',
#  'hami',
#  'santa marta',
#  'mutsu',
#  'nguiu',
#  'antas',
#  'henties bay',
#  'jasper',
#  'pevek',
#  'jutai',
#  'campbell river',
#  'xinzhou',
#  'satitoa',
#  'bonoua',
#  'riviere-au-renard',
#  'lensk',
#  'bontang',
#  'magadan',
#  'viligili',
#  'kathu',
#  'baykit',
#  'cabo san lucas',
#  'beringovskiy',
#  'ambodifototra',
#  'tucuman',
#  'bourail',
#  'gasa',
#  'talara',
#  'palmer',
#  'lucapa',
#  'paracuru',
#  'liaoyang',
#  'zhanakorgan',
#  'nakasongola',
#  'mao',
#  'deputatskiy',
#  'thinadhoo',
#  'minudasht',
#  'norman wells',
#  'ilo',
#  'alice springs',
#  'portland',
#  'komsomolskiy',
#  'muborak',
#  'yuzhno-yeniseyskiy',
#  'paamiut',
#  'astana',
#  'vanimo',
#  'podstepki',
#  'vung tau',
#  'bollnas',
#  'rovaniemi',
#  'guerrero negro',
#  'miraflores',
#  'cockburn town',
#  'ponazyrevo',
#  'muroto',
#  'sept-iles',
#  'biryusinsk',
#  'phonhong',
#  'tunduru',
#  'luderitz',
#  'orgun',
#  'kunming',
#  'xining',
#  'filadelfia',
#  'bayir',
#  'doha',
#  'attawapiskat',
#  'mount gambier',
#  'jacareacanga',
#  'warri',
#  'waipawa',
#  'jerome',
#  'bayeux',
#  'kandrian',
#  'chokurdakh',
#  'shache',
#  'aswan',
#  'mount isa',
#  'hovd',
#  'kihei',
#  'tynda',
#  'kutum',
#  'berlevag',
#  'anadyr',
#  'darnah',
#  'astorga',
#  'ojuelos de jalisco',
#  'soyo',
#  'formoso do araguaia',
#  'claremont',
#  'burley',
#  'yurginskoye',
#  'qui nhon',
#  'belyy yar',
#  'san pedro',
#  'shaowu',
#  'fairbanks',
#  'kruisfontein',
#  'katobu',
#  'matamoros',
#  'tera',
#  'leiva',
#  'mahebourg',
#  'beloha',
#  'pucallpa',
#  'mangan',
#  'christchurch',
#  'beitbridge',
#  'zhezkazgan',
#  'havoysund',
#  'luganville',
#  'erenhot',
#  'marinette',
#  'ixtapa',
#  'yar-sale',
#  'bilma',
#  'tiruvottiyur',
#  'kavaratti',
#  'methven',
#  'santa cruz de la palma',
#  'yeniseysk',
#  'springbok',
#  'lujan',
#  'presidencia roque saenz pena',
#  'rungata',
#  'santana do matos',
#  'sinop',
#  'grand gaube',
#  'arsk',
#  'kangaatsiaq',
#  'sentyabrskiy',
#  'hirara',
#  'nsanje',
#  'marsh harbour',
#  'delta',
#  'kokopo',
#  'santa fe',
#  'wukari',
#  'xinzhi',
#  'boa vista',
#  'shetpe',
#  'rawannawi',
#  'ishigaki',
#  'morondava',
#  'walvis bay',
#  'abu dhabi',
#  'amapa',
#  'ducheng',
#  'bud',
#  'raudeberg',
#  'saint-paul',
#  'malko tarnovo',
#  'campeche',
#  'manicore',
#  'hualmay',
#  'tessalit',
#  'lincoln',
#  'komsomolets',
#  'meyungs',
#  'lolua',
#  'gejiu',
#  'ocean city',
#  'yeletskiy',
#  'priyutnoye',
#  'evensk',
#  'reefton',
#  'buchanan',
#  'dingle',
#  'raymond',
#  'asyut',
#  'fort-shevchenko',
#  'boende',
#  'goderich',
#  'bubaque',
#  'skagastrond',
#  'leh',
#  'lavrentiya',
#  'oeiras do para',
#  'chandbali',
#  'rustenburg',
#  'colonia',
#  'cap malheureux',
#  'balagansk',
#  'hearst',
#  'liverpool',
#  'terrace',
#  'kemi',
#  'charters towers',
#  'saint-pierre',
#  'sabha',
#  'camacha',
#  'lakes entrance',
#  'rocha',
#  'yemelyanovo',
#  'moisei',
#  'piro',
#  'burnie',
#  'baoding',
#  'izhma',
#  'lahad datu',
#  'lata',
#  'shimoda',
#  'hambantota',
#  'bousso',
#  'chimore',
#  'biharamulo',
#  'gusinoye ozero',
#  'avera',
#  'racine',
#  'talaya',
#  'alofi',
#  'peniche',
#  'karratha',
#  'nanakuli',
#  'sisimiut',
#  'ajdabiya',
#  'mabaruma',
#  'nyrob',
#  'killam',
#  'fortuna',
#  'broken hill',
#  'bastia',
#  'muktagachha',
#  'japura',
#  'linqiong',
#  'erzin',
#  'esso',
#  'emerald',
#  'madang',
#  'griffith',
#  'bestobe',
#  'amga',
#  'kalabo',
#  'krivosheino',
#  'niquelandia',
#  'lorengau',
#  'santa maria da boa vista',
#  'mildura',
#  'gimli',
#  'tashtyp',
#  'betamcherla',
#  'zhangye',
#  'roald',
#  'sakakah',
#  'dhidhdhoo',
#  'port-cartier',
#  'hirna',
#  'balikpapan',
#  'kamsack',
#  'manacapuru',
#  'aginskoye',
#  'prado',
#  'madoc',
#  'remontnoye',
#  'faanui',
#  'balakhta',
#  'sampit',
#  'sao filipe',
#  'umzimvubu',
#  'swift current',
#  'magdalena',
#  'male',
#  'nome',
#  'kathmandu',
#  'tumannyy',
#  'khor',
#  'rawson',
#  'nuuk',
#  'cairns',
#  'iranshahr',
#  'bac lieu',
#  'north bend',
#  'kailua',
#  'varna',
#  'mazagao',
#  'bonavista',
#  'aflu',
#  'jumla',
#  'juneau',
#  'spas-demensk',
#  'carballo',
#  'warqla',
#  'ketchikan',
#  'rancho veloz',
#  'itarema',
#  'lianzhou',
#  'ossora',
#  'kuli',
#  'san quintin',
#  'riverton',
#  'starychi',
#  'akyab',
#  'sorumsand',
#  'port hardy',
#  'uyar',
#  'elko',
#  'samarai',
#  'northam',
#  'imeni poliny osipenko',
#  'khanion tou kokkini',
#  'smila',
#  'hede',
#  'pedernales',
#  'dongsheng',
#  'preobrazheniye',
#  'lampa',
#  'trincomalee',
#  'tuatapere',
#  'hobyo',
#  'bolungarvik',
#  'paita',
#  'el real de santa maria',
#  'gisborne',
#  'whitianga',
#  'wadena',
#  'athabasca',
#  'atasu',
#  'vao',
#  'ust-koksa',
#  'takoradi',
#  'gawan',
#  'viransehir',
#  'urengoy',
#  'chimoio',
#  'plaridel',
#  'dubti',
#  'port lincoln',
#  'kasongo-lunda',
#  'cartagena',
#  'puerto narino',
#  'belaya gora',
#  'safranbolu',
#  'waynesville',
#  'xuddur',
#  'amahai']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_pd = pd.DataFrame(columns=['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng', 'Max Temp',
              'Wind Speed'])

url = "http://api.openweathermap.org/data/2.5/weather?"


print("Beginning Data Retrieval")
print("-----------------------------")
i = 0

for city in cities:
    
    query_url = url + "appid=" + api_key + "&q=" + city.replace(" ", "+")
    try:
        city_json = requests.get(query_url).json()
        city_json
        cities_pd = cities_pd.append({'City': city_json['name'], 'Cloudiness': city_json['clouds']['all'], 
            'Country': city_json['sys']['country'], 'Date': city_json['dt'], 'Humidity': city_json['main']['humidity'], 
            'Lat': city_json['coord']['lat'], 'Lng': city_json['coord']['lon'], 
            'Max Temp': city_json['main']['temp_max'], 'Wind Speed': city_json['wind']['speed']}, ignore_index=True)
        i += 1
        print(f"Processing Record {i} of Set 1 | {city}")
    except (KeyError, IndexError):
        print(f"City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | sorong
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | eregli
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | camocim
# Processing Record 9 of Set 1 | balabac
# Processing Record 10 of Set 1 | comodoro rivadavia
# Processing Record 11 of Set 1 | adrar
# Processing Record 12 of Set 1 | daru
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | vila velha
# City not found. Skipping...
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | dunedin
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | pyapon
# Processing Record 21 of Set 1 | sindor
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | nagyigmand
# City not found. Skipping...
# Processing Record 24 of Set 1 | indramayu
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | brzeg dolny
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | touros
# Processing Record 33 of Set 1 | pochutla
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | ahipara
# Processing Record 36 of Set 1 | seymchan
# Processing Record 37 of Set 1 | hokitika
# Processing Record 38 of Set 1 | jalu
# Processing Record 39 of Set 1 | maningrida
# Processing Record 40 of Set 1 | chernyshevskiy
# Processing Record 41 of Set 1 | russell
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | yaan
# Processing Record 44 of Set 1 | hofn
# Processing Record 45 of Set 1 | sola
# Processing Record 46 of Set 1 | ryotsu
# City not found. Skipping...
# Processing Record 47 of Set 1 | ubatuba
# Processing Record 48 of Set 1 | clyde river
# City not found. Skipping...
# Processing Record 49 of Set 1 | vestmannaeyjar
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 51 of Set 1 | lithgow
# Processing Record 52 of Set 1 | east london
# Processing Record 53 of Set 1 | son la
# City not found. Skipping...
# Processing Record 54 of Set 1 | hobart
# Processing Record 55 of Set 1 | sawtell
# Processing Record 56 of Set 1 | allonnes
# Processing Record 57 of Set 1 | victoria
# Processing Record 58 of Set 1 | lagoa
# City not found. Skipping...
# Processing Record 59 of Set 1 | hilo
# Processing Record 60 of Set 1 | maine-soroa
# Processing Record 61 of Set 1 | podyuga
# Processing Record 62 of Set 1 | puerto ayora
# Processing Record 63 of Set 1 | marawi
# Processing Record 64 of Set 1 | tateyama
# Processing Record 65 of Set 1 | gazojak
# Processing Record 66 of Set 1 | chuy
# Processing Record 67 of Set 1 | port alfred
# Processing Record 68 of Set 1 | mar del plata
# Processing Record 69 of Set 1 | hermanus
# Processing Record 70 of Set 1 | klaksvik
# Processing Record 71 of Set 1 | gizo
# Processing Record 72 of Set 1 | ulladulla
# Processing Record 73 of Set 1 | jamestown
# Processing Record 74 of Set 1 | miles city
# Processing Record 75 of Set 1 | bethel
# City not found. Skipping...
# Processing Record 76 of Set 1 | soufriere
# Processing Record 77 of Set 1 | torbay
# Processing Record 78 of Set 1 | panaba
# Processing Record 79 of Set 1 | oistins
# Processing Record 80 of Set 1 | upernavik
# Processing Record 81 of Set 1 | porangatu
# Processing Record 82 of Set 1 | ballitoville
# Processing Record 83 of Set 1 | rosetta
# City not found. Skipping...
# Processing Record 84 of Set 1 | entre rios
# Processing Record 85 of Set 1 | khatanga
# Processing Record 86 of Set 1 | ikom
# Processing Record 87 of Set 1 | cayenne
# Processing Record 88 of Set 1 | leningradskiy
# Processing Record 89 of Set 1 | provideniya
# City not found. Skipping...
# Processing Record 90 of Set 1 | georgetown
# Processing Record 91 of Set 1 | tuktoyaktuk
# Processing Record 92 of Set 1 | dwarka
# City not found. Skipping...
# Processing Record 93 of Set 1 | dakar
# Processing Record 94 of Set 1 | oktyabrskiy
# Processing Record 95 of Set 1 | kedrovyy
# City not found. Skipping...
# Processing Record 96 of Set 1 | havelock
# Processing Record 97 of Set 1 | okha
# Processing Record 98 of Set 1 | hamilton
# Processing Record 99 of Set 1 | meulaboh
# Processing Record 100 of Set 1 | montego bay
# Processing Record 101 of Set 1 | cape canaveral
# Processing Record 102 of Set 1 | newport
# Processing Record 103 of Set 1 | chaupimarca
# Processing Record 104 of Set 1 | chachapoyas
# Processing Record 105 of Set 1 | xapuri
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 106 of Set 1 | padang
# Processing Record 107 of Set 1 | nadadores
# Processing Record 108 of Set 1 | golfito
# Processing Record 109 of Set 1 | saint-philippe
# Processing Record 110 of Set 1 | bilibino
# Processing Record 111 of Set 1 | aklavik
# Processing Record 112 of Set 1 | piacabucu
# Processing Record 113 of Set 1 | la romana
# Processing Record 114 of Set 1 | aksarka
# Processing Record 115 of Set 1 | bredasdorp
# Processing Record 116 of Set 1 | geraldton
# Processing Record 117 of Set 1 | praia
# Processing Record 118 of Set 1 | butaritari
# Processing Record 119 of Set 1 | temiscaming
# Processing Record 120 of Set 1 | port blair
# Processing Record 121 of Set 1 | cidreira
# City not found. Skipping...
# Processing Record 122 of Set 1 | carutapera
# Processing Record 123 of Set 1 | saldanha
# Processing Record 124 of Set 1 | thompson
# Processing Record 125 of Set 1 | codrington
# Processing Record 126 of Set 1 | saint george
# Processing Record 127 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 128 of Set 1 | lethem
# Processing Record 129 of Set 1 | pisco
# Processing Record 130 of Set 1 | zaraza
# Processing Record 131 of Set 1 | san patricio
# Processing Record 132 of Set 1 | cherskiy
# Processing Record 133 of Set 1 | namibe
# Processing Record 134 of Set 1 | constitucion
# Processing Record 135 of Set 1 | wum
# Processing Record 136 of Set 1 | avarua
# Processing Record 137 of Set 1 | los llanos de aridane
# Processing Record 138 of Set 1 | coquimbo
# Processing Record 139 of Set 1 | yeppoon
# Processing Record 140 of Set 1 | tautira
# Processing Record 141 of Set 1 | atambua
# Processing Record 142 of Set 1 | carnarvon
# Processing Record 143 of Set 1 | balkhash
# Processing Record 144 of Set 1 | karpogory
# Processing Record 145 of Set 1 | bathsheba
# Processing Record 146 of Set 1 | awjilah
# Processing Record 147 of Set 1 | srednekolymsk
# City not found. Skipping...
# Processing Record 148 of Set 1 | panguna
# City not found. Skipping...
# Processing Record 149 of Set 1 | road town
# Processing Record 150 of Set 1 | kaitangata
# Processing Record 151 of Set 1 | bowen
# Processing Record 152 of Set 1 | banjarmasin
# Processing Record 153 of Set 1 | margate
# Processing Record 154 of Set 1 | zyryanka
# Processing Record 155 of Set 1 | haines junction
# Processing Record 156 of Set 1 | cosolapa
# Processing Record 157 of Set 1 | salalah
# Processing Record 158 of Set 1 | caucaia
# Processing Record 159 of Set 1 | airai
# Processing Record 160 of Set 1 | korhogo
# Processing Record 161 of Set 1 | labytnangi
# City not found. Skipping...
# Processing Record 162 of Set 1 | nikolskoye
# Processing Record 163 of Set 1 | labuhan
# Processing Record 164 of Set 1 | fiditi
# Processing Record 165 of Set 1 | zabid
# Processing Record 166 of Set 1 | barrow
# Processing Record 167 of Set 1 | kahului
# Processing Record 168 of Set 1 | port-gentil
# City not found. Skipping...
# Processing Record 169 of Set 1 | iquique
# Processing Record 170 of Set 1 | bambous virieux
# Processing Record 171 of Set 1 | queanbeyan
# Processing Record 172 of Set 1 | red bluff
# Processing Record 173 of Set 1 | makakilo city
# Processing Record 174 of Set 1 | saskylakh
# Processing Record 175 of Set 1 | sambava
# Processing Record 176 of Set 1 | vagur
# Processing Record 177 of Set 1 | abashiri
# Processing Record 178 of Set 1 | maragogi
# Processing Record 179 of Set 1 | olinda
# Processing Record 180 of Set 1 | aykhal
# Processing Record 181 of Set 1 | kodiak
# Processing Record 182 of Set 1 | la ronge
# Processing Record 183 of Set 1 | vardo
# Processing Record 184 of Set 1 | benemerito de las americas
# Processing Record 185 of Set 1 | san-pedro
# Processing Record 186 of Set 1 | ust-nera
# Processing Record 187 of Set 1 | havre-saint-pierre
# Processing Record 188 of Set 1 | port elizabeth
# Processing Record 189 of Set 1 | ponta do sol
# Processing Record 190 of Set 1 | agadir
# Processing Record 191 of Set 1 | ilulissat
# Processing Record 192 of Set 1 | fort nelson
# Processing Record 193 of Set 1 | egvekinot
# Processing Record 194 of Set 1 | bogande
# Processing Record 195 of Set 1 | yumen
# Processing Record 196 of Set 1 | faya
# Processing Record 197 of Set 1 | florianopolis
# City not found. Skipping...
# Processing Record 198 of Set 1 | chapais
# Processing Record 199 of Set 1 | hasaki
# Processing Record 200 of Set 1 | wyszkow
# Processing Record 201 of Set 1 | arcata
# Processing Record 202 of Set 1 | kaa-khem
# Processing Record 203 of Set 1 | quelimane
# Processing Record 204 of Set 1 | tual
# City not found. Skipping...
# Processing Record 205 of Set 1 | inhambane
# Processing Record 206 of Set 1 | longjiang
# City not found. Skipping...
# Processing Record 207 of Set 1 | darhan
# Processing Record 208 of Set 1 | ostrovnoy
# Processing Record 209 of Set 1 | amarante do maranhao
# Processing Record 210 of Set 1 | hundested
# Processing Record 211 of Set 1 | kiunga
# Processing Record 212 of Set 1 | pitimbu
# Processing Record 213 of Set 1 | kyren
# Processing Record 214 of Set 1 | narsaq
# Processing Record 215 of Set 1 | lebu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 216 of Set 1 | laukaa
# Processing Record 217 of Set 1 | laguna
# Processing Record 218 of Set 1 | iqaluit
# Processing Record 219 of Set 1 | mossendjo
# Processing Record 220 of Set 1 | caborca
# Processing Record 221 of Set 1 | ugoofaaru
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 222 of Set 1 | vostok
# Processing Record 223 of Set 1 | pendencias
# Processing Record 224 of Set 1 | kachug
# Processing Record 225 of Set 1 | kontagora
# Processing Record 226 of Set 1 | acapulco
# Processing Record 227 of Set 1 | huilong
# Processing Record 228 of Set 1 | sabang
# Processing Record 229 of Set 1 | katsuura
# Processing Record 230 of Set 1 | sitka
# Processing Record 231 of Set 1 | grand bend
# Processing Record 232 of Set 1 | severo-kurilsk
# Processing Record 233 of Set 1 | salinopolis
# Processing Record 234 of Set 1 | coihaique
# Processing Record 235 of Set 1 | kavieng
# Processing Record 236 of Set 1 | cabrobo
# Processing Record 237 of Set 1 | souillac
# City not found. Skipping...
# Processing Record 238 of Set 1 | hami
# Processing Record 239 of Set 1 | santa marta
# Processing Record 240 of Set 1 | mutsu
# City not found. Skipping...
# Processing Record 241 of Set 1 | antas
# Processing Record 242 of Set 1 | henties bay
# Processing Record 243 of Set 1 | jasper
# Processing Record 244 of Set 1 | pevek
# Processing Record 245 of Set 1 | jutai
# Processing Record 246 of Set 1 | campbell river
# Processing Record 247 of Set 1 | xinzhou
# City not found. Skipping...
# Processing Record 248 of Set 1 | bonoua
# Processing Record 249 of Set 1 | riviere-au-renard
# Processing Record 250 of Set 1 | lensk
# Processing Record 251 of Set 1 | bontang
# Processing Record 252 of Set 1 | magadan
# City not found. Skipping...
# Processing Record 253 of Set 1 | kathu
# Processing Record 254 of Set 1 | baykit
# Processing Record 255 of Set 1 | cabo san lucas
# Processing Record 256 of Set 1 | beringovskiy
# City not found. Skipping...
# Processing Record 257 of Set 1 | tucuman
# Processing Record 258 of Set 1 | bourail
# Processing Record 259 of Set 1 | gasa
# Processing Record 260 of Set 1 | talara
# Processing Record 261 of Set 1 | palmer
# Processing Record 262 of Set 1 | lucapa
# Processing Record 263 of Set 1 | paracuru
# Processing Record 264 of Set 1 | liaoyang
# Processing Record 265 of Set 1 | zhanakorgan
# Processing Record 266 of Set 1 | nakasongola
# Processing Record 267 of Set 1 | mao
# Processing Record 268 of Set 1 | deputatskiy
# Processing Record 269 of Set 1 | thinadhoo
# Processing Record 270 of Set 1 | minudasht
# Processing Record 271 of Set 1 | norman wells
# Processing Record 272 of Set 1 | ilo
# Processing Record 273 of Set 1 | alice springs
# Processing Record 274 of Set 1 | portland
# Processing Record 275 of Set 1 | komsomolskiy
# Processing Record 276 of Set 1 | muborak
# City not found. Skipping...
# Processing Record 277 of Set 1 | paamiut
# Processing Record 278 of Set 1 | astana
# Processing Record 279 of Set 1 | vanimo
# Processing Record 280 of Set 1 | podstepki
# Processing Record 281 of Set 1 | vung tau
# Processing Record 282 of Set 1 | bollnas
# Processing Record 283 of Set 1 | rovaniemi
# Processing Record 284 of Set 1 | guerrero negro
# Processing Record 285 of Set 1 | miraflores
# Processing Record 286 of Set 1 | cockburn town
# Processing Record 287 of Set 1 | ponazyrevo
# Processing Record 288 of Set 1 | muroto
# Processing Record 289 of Set 1 | sept-iles
# Processing Record 290 of Set 1 | biryusinsk
# Processing Record 291 of Set 1 | phonhong
# City not found. Skipping...
# Processing Record 292 of Set 1 | luderitz
# City not found. Skipping...
# Processing Record 293 of Set 1 | kunming
# Processing Record 294 of Set 1 | xining
# Processing Record 295 of Set 1 | filadelfia
# Processing Record 296 of Set 1 | bayir
# Processing Record 297 of Set 1 | doha
# City not found. Skipping...
# Processing Record 298 of Set 1 | mount gambier
# Processing Record 299 of Set 1 | jacareacanga
# Processing Record 300 of Set 1 | warri
# Processing Record 301 of Set 1 | waipawa
# Processing Record 302 of Set 1 | jerome
# Processing Record 303 of Set 1 | bayeux
# Processing Record 304 of Set 1 | kandrian
# Processing Record 305 of Set 1 | chokurdakh
# Processing Record 306 of Set 1 | shache
# Processing Record 307 of Set 1 | aswan
# Processing Record 308 of Set 1 | mount isa
# Processing Record 309 of Set 1 | hovd
# Processing Record 310 of Set 1 | kihei
# Processing Record 311 of Set 1 | tynda
# Processing Record 312 of Set 1 | kutum
# Processing Record 313 of Set 1 | berlevag
# Processing Record 314 of Set 1 | anadyr
# Processing Record 315 of Set 1 | darnah
# Processing Record 316 of Set 1 | astorga
# Processing Record 317 of Set 1 | ojuelos de jalisco
# Processing Record 318 of Set 1 | soyo
# City not found. Skipping...
# Processing Record 319 of Set 1 | claremont
# Processing Record 320 of Set 1 | burley
# Processing Record 321 of Set 1 | yurginskoye
# City not found. Skipping...
# Processing Record 322 of Set 1 | belyy yar
# Processing Record 323 of Set 1 | san pedro
# Processing Record 324 of Set 1 | shaowu
# Processing Record 325 of Set 1 | fairbanks
# Processing Record 326 of Set 1 | kruisfontein
# Processing Record 327 of Set 1 | katobu
# Processing Record 328 of Set 1 | matamoros
# Processing Record 329 of Set 1 | tera
# Processing Record 330 of Set 1 | leiva
# Processing Record 331 of Set 1 | mahebourg
# Processing Record 332 of Set 1 | beloha
# Processing Record 333 of Set 1 | pucallpa
# Processing Record 334 of Set 1 | mangan
# Processing Record 335 of Set 1 | christchurch
# Processing Record 336 of Set 1 | beitbridge
# Processing Record 337 of Set 1 | zhezkazgan
# Processing Record 338 of Set 1 | havoysund
# Processing Record 339 of Set 1 | luganville
# Processing Record 340 of Set 1 | erenhot
# Processing Record 341 of Set 1 | marinette
# Processing Record 342 of Set 1 | ixtapa
# Processing Record 343 of Set 1 | yar-sale
# Processing Record 344 of Set 1 | bilma
# City not found. Skipping...
# Processing Record 345 of Set 1 | kavaratti
# Processing Record 346 of Set 1 | methven
# Processing Record 347 of Set 1 | santa cruz de la palma
# Processing Record 348 of Set 1 | yeniseysk
# Processing Record 349 of Set 1 | springbok
# Processing Record 350 of Set 1 | lujan
# Processing Record 351 of Set 1 | presidencia roque saenz pena
# City not found. Skipping...
# Processing Record 352 of Set 1 | santana do matos
# Processing Record 353 of Set 1 | sinop
# Processing Record 354 of Set 1 | grand gaube
# Processing Record 355 of Set 1 | arsk
# Processing Record 356 of Set 1 | kangaatsiaq
# City not found. Skipping...
# Processing Record 357 of Set 1 | hirara
# Processing Record 358 of Set 1 | nsanje
# Processing Record 359 of Set 1 | marsh harbour
# Processing Record 360 of Set 1 | delta
# Processing Record 361 of Set 1 | kokopo
# Processing Record 362 of Set 1 | santa fe
# Processing Record 363 of Set 1 | wukari
# Processing Record 364 of Set 1 | xinzhi
# Processing Record 365 of Set 1 | boa vista
# Processing Record 366 of Set 1 | shetpe
# City not found. Skipping...
# Processing Record 367 of Set 1 | ishigaki
# Processing Record 368 of Set 1 | morondava
# Processing Record 369 of Set 1 | walvis bay
# Processing Record 370 of Set 1 | abu dhabi
# Processing Record 371 of Set 1 | amapa
# Processing Record 372 of Set 1 | ducheng
# Processing Record 373 of Set 1 | bud
# Processing Record 374 of Set 1 | raudeberg
# Processing Record 375 of Set 1 | saint-paul
# Processing Record 376 of Set 1 | malko tarnovo
# Processing Record 377 of Set 1 | campeche
# Processing Record 378 of Set 1 | manicore
# Processing Record 379 of Set 1 | hualmay
# Processing Record 380 of Set 1 | tessalit
# Processing Record 381 of Set 1 | lincoln
# Processing Record 382 of Set 1 | komsomolets
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 383 of Set 1 | gejiu
# Processing Record 384 of Set 1 | ocean city
# City not found. Skipping...
# Processing Record 385 of Set 1 | priyutnoye
# Processing Record 386 of Set 1 | evensk
# City not found. Skipping...
# Processing Record 387 of Set 1 | buchanan
# Processing Record 388 of Set 1 | dingle
# Processing Record 389 of Set 1 | raymond
# Processing Record 390 of Set 1 | asyut
# Processing Record 391 of Set 1 | fort-shevchenko
# Processing Record 392 of Set 1 | boende
# Processing Record 393 of Set 1 | goderich
# Processing Record 394 of Set 1 | bubaque
# City not found. Skipping...
# Processing Record 395 of Set 1 | leh
# Processing Record 396 of Set 1 | lavrentiya
# Processing Record 397 of Set 1 | oeiras do para
# Processing Record 398 of Set 1 | chandbali
# Processing Record 399 of Set 1 | rustenburg
# Processing Record 400 of Set 1 | colonia
# Processing Record 401 of Set 1 | cap malheureux
# Processing Record 402 of Set 1 | balagansk
# Processing Record 403 of Set 1 | hearst
# Processing Record 404 of Set 1 | liverpool
# Processing Record 405 of Set 1 | terrace
# Processing Record 406 of Set 1 | kemi
# Processing Record 407 of Set 1 | charters towers
# Processing Record 408 of Set 1 | saint-pierre
# Processing Record 409 of Set 1 | sabha
# Processing Record 410 of Set 1 | camacha
# Processing Record 411 of Set 1 | lakes entrance
# Processing Record 412 of Set 1 | rocha
# Processing Record 413 of Set 1 | yemelyanovo
# Processing Record 414 of Set 1 | moisei
# Processing Record 415 of Set 1 | piro
# Processing Record 416 of Set 1 | burnie
# Processing Record 417 of Set 1 | baoding
# Processing Record 418 of Set 1 | izhma
# Processing Record 419 of Set 1 | lahad datu
# Processing Record 420 of Set 1 | lata
# Processing Record 421 of Set 1 | shimoda
# Processing Record 422 of Set 1 | hambantota
# City not found. Skipping...
# Processing Record 423 of Set 1 | chimore
# Processing Record 424 of Set 1 | biharamulo
# Processing Record 425 of Set 1 | gusinoye ozero
# Processing Record 426 of Set 1 | avera
# Processing Record 427 of Set 1 | racine
# Processing Record 428 of Set 1 | talaya
# Processing Record 429 of Set 1 | alofi
# Processing Record 430 of Set 1 | peniche
# Processing Record 431 of Set 1 | karratha
# Processing Record 432 of Set 1 | nanakuli
# Processing Record 433 of Set 1 | sisimiut
# Processing Record 434 of Set 1 | ajdabiya
# Processing Record 435 of Set 1 | mabaruma
# Processing Record 436 of Set 1 | nyrob
# Processing Record 437 of Set 1 | killam
# Processing Record 438 of Set 1 | fortuna
# Processing Record 439 of Set 1 | broken hill
# Processing Record 440 of Set 1 | bastia
# City not found. Skipping...
# Processing Record 441 of Set 1 | japura
# Processing Record 442 of Set 1 | linqiong
# Processing Record 443 of Set 1 | erzin
# Processing Record 444 of Set 1 | esso
# Processing Record 445 of Set 1 | emerald
# Processing Record 446 of Set 1 | madang
# Processing Record 447 of Set 1 | griffith
# Processing Record 448 of Set 1 | bestobe
# Processing Record 449 of Set 1 | amga
# Processing Record 450 of Set 1 | kalabo
# Processing Record 451 of Set 1 | krivosheino
# Processing Record 452 of Set 1 | niquelandia
# Processing Record 453 of Set 1 | lorengau
# Processing Record 454 of Set 1 | santa maria da boa vista
# Processing Record 455 of Set 1 | mildura
# Processing Record 456 of Set 1 | gimli
# Processing Record 457 of Set 1 | tashtyp
# Processing Record 458 of Set 1 | betamcherla
# Processing Record 459 of Set 1 | zhangye
# Processing Record 460 of Set 1 | roald
# City not found. Skipping...
# Processing Record 461 of Set 1 | dhidhdhoo
# Processing Record 462 of Set 1 | port-cartier
# Processing Record 463 of Set 1 | hirna
# Processing Record 464 of Set 1 | balikpapan
# Processing Record 465 of Set 1 | kamsack
# Processing Record 466 of Set 1 | manacapuru
# Processing Record 467 of Set 1 | aginskoye
# Processing Record 468 of Set 1 | prado
# Processing Record 469 of Set 1 | madoc
# Processing Record 470 of Set 1 | remontnoye
# Processing Record 471 of Set 1 | faanui
# Processing Record 472 of Set 1 | balakhta
# Processing Record 473 of Set 1 | sampit
# Processing Record 474 of Set 1 | sao filipe
# City not found. Skipping...
# Processing Record 475 of Set 1 | swift current
# Processing Record 476 of Set 1 | magdalena
# Processing Record 477 of Set 1 | male
# Processing Record 478 of Set 1 | nome
# Processing Record 479 of Set 1 | kathmandu
# City not found. Skipping...
# Processing Record 480 of Set 1 | khor
# Processing Record 481 of Set 1 | rawson
# Processing Record 482 of Set 1 | nuuk
# Processing Record 483 of Set 1 | cairns
# Processing Record 484 of Set 1 | iranshahr
# City not found. Skipping...
# Processing Record 485 of Set 1 | north bend
# Processing Record 486 of Set 1 | kailua
# Processing Record 487 of Set 1 | varna
# Processing Record 488 of Set 1 | mazagao
# Processing Record 489 of Set 1 | bonavista
# City not found. Skipping...
# Processing Record 490 of Set 1 | jumla
# Processing Record 491 of Set 1 | juneau
# Processing Record 492 of Set 1 | spas-demensk
# Processing Record 493 of Set 1 | carballo
# City not found. Skipping...
# Processing Record 494 of Set 1 | ketchikan
# Processing Record 495 of Set 1 | rancho veloz
# Processing Record 496 of Set 1 | itarema
# Processing Record 497 of Set 1 | lianzhou
# Processing Record 498 of Set 1 | ossora
# Processing Record 499 of Set 1 | kuli
# Processing Record 500 of Set 1 | san quintin
# Processing Record 501 of Set 1 | riverton
# Processing Record 502 of Set 1 | starychi
# City not found. Skipping...
# Processing Record 503 of Set 1 | sorumsand
# Processing Record 504 of Set 1 | port hardy
# Processing Record 505 of Set 1 | uyar
# Processing Record 506 of Set 1 | elko
# Processing Record 507 of Set 1 | samarai
# Processing Record 508 of Set 1 | northam
# Processing Record 509 of Set 1 | imeni poliny osipenko
# City not found. Skipping...
# Processing Record 510 of Set 1 | smila
# Processing Record 511 of Set 1 | hede
# Processing Record 512 of Set 1 | pedernales
# Processing Record 513 of Set 1 | dongsheng
# Processing Record 514 of Set 1 | preobrazheniye
# Processing Record 515 of Set 1 | lampa
# Processing Record 516 of Set 1 | trincomalee
# Processing Record 517 of Set 1 | tuatapere
# Processing Record 518 of Set 1 | hobyo
# City not found. Skipping...
# Processing Record 519 of Set 1 | paita
# Processing Record 520 of Set 1 | el real de santa maria
# Processing Record 521 of Set 1 | gisborne
# Processing Record 522 of Set 1 | whitianga
# Processing Record 523 of Set 1 | wadena
# Processing Record 524 of Set 1 | athabasca
# Processing Record 525 of Set 1 | atasu
# Processing Record 526 of Set 1 | vao
# Processing Record 527 of Set 1 | ust-koksa
# Processing Record 528 of Set 1 | takoradi
# Processing Record 529 of Set 1 | gawan
# Processing Record 530 of Set 1 | viransehir
# Processing Record 531 of Set 1 | urengoy
# Processing Record 532 of Set 1 | chimoio
# Processing Record 533 of Set 1 | plaridel
# Processing Record 534 of Set 1 | dubti
# Processing Record 535 of Set 1 | port lincoln
# Processing Record 536 of Set 1 | kasongo-lunda
# Processing Record 537 of Set 1 | cartagena
# Processing Record 538 of Set 1 | puerto narino
# Processing Record 539 of Set 1 | belaya gora
# Processing Record 540 of Set 1 | safranbolu
# Processing Record 541 of Set 1 | waynesville
# Processing Record 542 of Set 1 | xuddur
# Processing Record 543 of Set 1 | amahai

# %%
cities_pd.to_csv("cities_output.csv")

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_pd.head()
# Out:
#         City Cloudiness Country        Date Humidity    Lat     Lng  Max Temp  \
# 0    Ushuaia         20      AR  1563937101       80 -54.81  -68.31   272.150
# 1  Busselton         98      AU  1563937102       54 -33.64  115.35   290.370
# 2      Kapaa         75      US  1563937102       70  22.08 -159.32   302.150
# 3     Sorong        100      ID  1563937102       76  -0.86  131.25   300.722
# 4      Vaini         40      IN  1563937102       88  15.34   74.49   296.150
#
#    Wind Speed
# 0        3.60
# 1        7.16
# 2        6.20
# 3        4.12
# 4        7.20

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities_pd["Lat"], cities_pd["Max Temp"], marker='o', color="blue", 
    alpha=0.3, edgecolors="black")
plt.title("City Latitude vs. Max Temperature (7/23/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)");
plt.grid()
plt.savefig("max-temp.png")

# %%
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_pd["Lat"], cities_pd["Humidity"], marker='o', color="blue", 
    alpha=0.3, edgecolors="black")
plt.title("City Latitude vs. Humidity (7/23/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)");
plt.grid()
plt.savefig("humidity.png")

# %%
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_pd["Lat"], cities_pd["Cloudiness"], marker='o', color="blue", 
    alpha=0.3, edgecolors="black")
plt.title("City Latitude vs. Cloudiness (7/23/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)");
plt.grid()
plt.savefig("cloudy.png")

# %%
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_pd["Lat"], cities_pd["Wind Speed"], marker='o', color="blue", 
    alpha=0.3, edgecolors="black")
plt.title("City Latitude vs. Wind Speed (7/23/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)");
plt.grid()
plt.savefig("wind.png")

# %%
plt.show()
